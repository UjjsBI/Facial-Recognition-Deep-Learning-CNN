# %% [markdown]
# # 📌 Step 1: Install Required Libraries

# %%
# !pip install kaggle --quiet
# !pip install tensorflow matplotlib seaborn --quiet

# %% [markdown]
# # 📌 Step 2: Upload Your Kaggle API Token
# Go to https://www.kaggle.com/settings
#
# Scroll down to “API” and click “Create New API Token”
#
# Upload the kaggle.json file in Colab

# %%
kaggle_api = '/content/sample_data/kaggle.json'

# %%
# Copy Kaggle API Key from Drive to .kaggle/
# !mkdir -p ~/.kaggle

# %%
# !cp /content/sample_data/kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # 📌 Step 3: Download FER2013 Dataset from Kaggle

# %%
# !kaggle datasets download -d msambare/fer2013
# !unzip -q fer2013.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#   0% 0.00/60.3M [00:00<?, ?B/s]
# 100% 60.3M/60.3M [00:00<00:00, 988MB/s]

# %% [markdown]
# # 📌 Step 4: Set Up Image Data Loaders

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Base directory
train_dir = "/content/train"
test_dir = "/content/test"

# Create ImageDataGenerator with validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% of training data for validation
)

# Training generator (80% of train data)
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation generator (20% of train data)
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Test generator (no split needed)
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 📌 Step 5: Build the CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       819,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 839,047 (3.20 MB)
#  Trainable params: 839,047 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 📌 Step 6: Train the Model

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.2503 - loss: 1.8199 - val_accuracy: 0.3473 - val_loss: 1.6363
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.3602 - loss: 1.6297 - val_accuracy: 0.4337 - val_loss: 1.5000
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.4074 - loss: 1.5246 - val_accuracy: 0.4379 - val_loss: 1.4482
# Epoch 4/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.4341 - loss: 1.4593 - val_accuracy: 0.4673 - val_loss: 1.3922
# Epoch 5/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.4493 - loss: 1.4292 - val_accuracy: 0.4816 - val_loss: 1.3652
# Epoch 6/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.4614 - loss: 1.3948 - val_accuracy: 0.4889 - val_loss: 1.3443
# Epoch 7/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.4759 - loss: 1.3651 - val_accuracy: 0.5037 - val_loss: 1.3135
# Epoch 8/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.4874 - loss: 1.3295 - val_accuracy: 0.5114 - val_loss: 1.2872
# Epoch 9/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.4996 - loss: 1.2983 - val_accuracy: 0.5086 - val_loss: 1.2835
# Epoch 10/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5124 - loss: 1.2743 - val_accuracy: 0.5156 - val_loss: 1.2810
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.5190 - loss: 1.2496 - val_accuracy: 0.5205 - val_loss: 1.2617
# Epoch 12/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.5330 - loss: 1.2372 - val_accuracy: 0.5198 - val_loss: 1.2518
# Epoch 13/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5342 - loss: 1.2127 - val_accuracy: 0.5208 - val_loss: 1.2441
# Epoch 14/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.5423 - loss: 1.2003 - val_accuracy: 0.5271 - val_loss: 1.2372
# Epoch 15/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.5614 - loss: 1.1593 - val_accuracy: 0.5356 - val_loss: 1.2362
# Epoch 16/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.5597 - loss: 1.1560 - val_accuracy: 0.5365 - val_loss: 1.2374
# Epoch 17/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.5763 - loss: 1.1150 - val_accuracy: 0.5365 - val_loss: 1.2257
# Epoch 18/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.5786 - loss: 1.0893 - val_accuracy: 0.5466 - val_loss: 1.2237
# Epoch 19/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.5856 - loss: 1.0799 - val_accuracy: 0.5436 - val_loss: 1.2245
# Epoch 20/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5907 - loss: 1.0662 - val_accuracy: 0.5407 - val_loss: 1.2285
# Epoch 21/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.5915 - loss: 1.0547 - val_accuracy: 0.5442 - val_loss: 1.2346
# Epoch 22/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.5965 - loss: 1.0445 - val_accuracy: 0.5442 - val_loss: 1.2311
# Epoch 23/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6060 - loss: 1.0282 - val_accuracy: 0.5414 - val_loss: 1.2436
# Epoch 24/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6055 - loss: 1.0199 - val_accuracy: 0.5497 - val_loss: 1.2318
# Epoch 25/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.6204 - loss: 0.9961 - val_accuracy: 0.5537 - val_loss: 1.2250
# Epoch 26/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6250 - loss: 0.9624 - val_accuracy: 0.5464 - val_loss: 1.2332
# Epoch 27/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.6350 - loss: 0.9629 - val_accuracy: 0.5436 - val_loss: 1.2426
# Epoch 28/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.6299 - loss: 0.9589 - val_accuracy: 0.5523 - val_loss: 1.2329
# Epoch 29/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6397 - loss: 0.9423 - val_accuracy: 0.5497 - val_loss: 1.2472
# Epoch 30/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6470 - loss: 0.9408 - val_accuracy: 0.5534 - val_loss: 1.2422
# Epoch 31/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.6493 - loss: 0.9169 - val_accuracy: 0.5468 - val_loss: 1.2591
# Epoch 32/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6443 - loss: 0.9218 - val_accuracy: 0.5483 - val_loss: 1.2573
# Epoch 33/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6581 - loss: 0.8959 - val_accuracy: 0.5483 - val_loss: 1.2592
# Epoch 34/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.6594 - loss: 0.8868 - val_accuracy: 0.5572 - val_loss: 1.2791
# Epoch 35/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6653 - loss: 0.8911 - val_accuracy: 0.5473 - val_loss: 1.2945
# Epoch 36/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6646 - loss: 0.8721 - val_accuracy: 0.5525 - val_loss: 1.2584
# Epoch 37/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6701 - loss: 0.8563 - val_accuracy: 0.5529 - val_loss: 1.2711
# Epoch 38/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6745 - loss: 0.8500 - val_accuracy: 0.5537 - val_loss: 1.2835
# Epoch 39/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6805 - loss: 0.8356 - val_accuracy: 0.5536 - val_loss: 1.2939
# Epoch 40/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6767 - loss: 0.8402 - val_accuracy: 0.5532 - val_loss: 1.2991
# Epoch 41/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.6798 - loss: 0.8303 - val_accuracy: 0.5473 - val_loss: 1.2829
# Epoch 42/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6752 - loss: 0.8351 - val_accuracy: 0.5469 - val_loss: 1.2965
# Epoch 43/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6817 - loss: 0.8227 - val_accuracy: 0.5506 - val_loss: 1.2926
# Epoch 44/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.6890 - loss: 0.8029 - val_accuracy: 0.5581 - val_loss: 1.3017
# Epoch 45/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6859 - loss: 0.7983 - val_accuracy: 0.5515 - val_loss: 1.3009
# Epoch 46/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6906 - loss: 0.7895 - val_accuracy: 0.5548 - val_loss: 1.3317
# Epoch 47/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6981 - loss: 0.7914 - val_accuracy: 0.5504 - val_loss: 1.3193
# Epoch 48/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6915 - loss: 0.7949 - val_accuracy: 0.5550 - val_loss: 1.3191
# Epoch 49/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.6919 - loss: 0.7869 - val_accuracy: 0.5550 - val_loss: 1.3272
# Epoch 50/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.
100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7540 - loss: 0.6430 - val_accuracy: 0.5551 - val_loss: 1.4027
# Epoch 81/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7502 - loss: 0.6459 - val_accuracy: 0.5595 - val_loss: 1.4284
# Epoch 82/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7516 - loss: 0.6381 - val_accuracy: 0.5565 - val_loss: 1.4348
# Epoch 83/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7527 - loss: 0.6484 - val_accuracy: 0.5522 - val_loss: 1.4060
# Epoch 84/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7580 - loss: 0.6328 - val_accuracy: 0.5555 - val_loss: 1.4458
# Epoch 85/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7602 - loss: 0.6215 - val_accuracy: 0.5532 - val_loss: 1.3945
# Epoch 86/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7543 - loss: 0.6234 - val_accuracy: 0.5522 - val_loss: 1.4234
# Epoch 87/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7531 - loss: 0.6281 - val_accuracy: 0.5522 - val_loss: 1.3887
# Epoch 88/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7622 - loss: 0.6243 - val_accuracy: 0.5525 - val_loss: 1.4391
# Epoch 89/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.7656 - loss: 0.6106 - val_accuracy: 0.5523 - val_loss: 1.4328
# Epoch 90/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.7637 - loss: 0.6197 - val_accuracy: 0.5509 - val_loss: 1.4409
# Epoch 91/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7687 - loss: 0.6168 - val_accuracy: 0.5529 - val_loss: 1.4525
# Epoch 92/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7661 - loss: 0.6022 - val_accuracy: 0.5523 - val_loss: 1.4186
# Epoch 93/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7602 - loss: 0.6209 - val_accuracy: 0.5529 - val_loss: 1.4525
# Epoch 94/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7680 - loss: 0.5971 - val_accuracy: 0.5513 - val_loss: 1.4507
# Epoch 95/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7643 - loss: 0.6116 - val_accuracy: 0.5557 - val_loss: 1.4498
# Epoch 96/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7674 - loss: 0.5978 - val_accuracy: 0.5557 - val_loss: 1.4699
# Epoch 97/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7773 - loss: 0.5723 - val_accuracy: 0.5476 - val_loss: 1.4635
# Epoch 98/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7731 - loss: 0.5905 - val_accuracy: 0.5508 - val_loss: 1.4860
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7675 - loss: 0.5977 - val_accuracy: 0.5530 - val_loss: 1.4622
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7729 - loss: 0.5759 - val_accuracy: 0.5490 - val_loss: 1.4595

# %% [markdown]
# # 📌 Step 7: Evaluate on Test Data

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.5158 - loss: 1.5105
# Test Accuracy: 0.5648

# %% [markdown]
# # 📌 Step 8: Plot Training and Validation Metrics

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Valid')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 📌 Step 9: Inference on a single image

# %%
class_labels = list(train_generator.class_indices.keys())

# %%
class_labels
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
import os

def predict_emotion(img_path):
    # Get actual class name from file path
    actual_label = os.path.basename(os.path.dirname(img_path))

    # Load and preprocess image
    img = image.load_img(img_path, color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    # Predict
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    predicted_label = class_labels[predicted_class]

    # Display image with actual & predicted label
    plt.imshow(img_array[0].squeeze(), cmap='gray')
    plt.title(f"Actual: {actual_label.capitalize()} | Predicted: {predicted_label.capitalize()}")
    plt.axis('off')
    plt.show()

# %%
predict_emotion("/content/test/happy/PrivateTest_13103594.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step

# %%
predict_emotion("/content/test/surprise/PrivateTest_13683211.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
predict_emotion("/content/test/fear/PrivateTest_11014592.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
predict_emotion("/content/test/sad/PrivateTest_10814167.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
